# %% [markdown]
# # EDA & T TEST
# # ASSIGNMENT
#
# # Prince pal singh - 0854378
# # Ankita Vashisht - 0854392
# # Swati kumari – 0850708
#
# # Research question are at the bottom of the code.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind

# Load dataset
data = pd.read_csv("C:/Users/ankuv/Downloads/Heart Disease data.csv")

# %%
# Display the first few rows
print(data.head())

# Summary of the dataset
print(data.info())

# Statistical summary of numerical columns
print(data.describe())

# Check for missing values
print(data.isnull().sum())
# Out:
#    Age  Sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       1025 non-null   int64
#  1   Sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
# ...

# %%
# Mean, Median, Mode for 'Age'
print(data['Age'].mean())
print(data['Age'].median())
print(data['Age'].mode())

# Standard deviation and variance for 'chol'
print(data['chol'].std())
print(data['chol'].var())
# Out:
# 54.43414634146342
# 56.0
# 0    58
# Name: Age, dtype: int64
# 51.59251020618206
# 2661.787109375

# %%
# Histogram for 'Age'
plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], kde=True)
plt.title('Age Distribution')
plt.show()
# Out:
# C:\Users\ankuv\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Boxplot for 'chol' by 'Sex'
plt.figure(figsize=(10, 6))
sns.boxplot(x='Sex', y='chol', data=data)
plt.title('Cholesterol Levels by Sex')
plt.show()

# %%
# Scatter plot for 'Age' vs 'chol'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='chol', hue='target', data=data)
plt.title('Age vs Cholesterol Levels (Colored by Target)')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # For T-testing, let's compare the cholesterol levels (chol) between two groups,
# # such as those with and without heart disease (target).

# %%
import pandas as pd
from scipy import stats

# Load the dataset
heart_data = pd.read_csv("C:/Users/ankuv/Downloads/Heart Disease data.csv")

# 1. One-Sample T-Test
# Hypothesis: H0: The mean cholesterol level is equal to 200, H1: The mean cholesterol level is not equal to 200
cholesterol_mean = 200

# Perform the one-sample t-test
t_statistic, p_value = stats.ttest_1samp(heart_data['chol'], cholesterol_mean)

print("One-Sample T-Test")
print(f"Hypotheses:")
print(f"H0: The mean cholesterol level is 200.")
print(f"H1: The mean cholesterol level is not 200.\n")

print(f"Results:")
print(f"T-statistic: {t_statistic:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Conclusion: Reject the null hypothesis (H0). The mean cholesterol level is significantly different from 200.\n")
else:
    print("Conclusion: Fail to reject the null hypothesis (H0). No significant difference from 200.\n")


# 2. Two-Sample T-Test
# Hypothesis: H0: The mean cholesterol levels are equal between the two groups, H1: The mean cholesterol levels are not equal between the two groups

# Separate the data into two groups based on the target variable
chol_with_disease = heart_data[heart_data['target'] == 1]['chol']
chol_without_disease = heart_data[heart_data['target'] == 0]['chol']

# Perform the two-sample t-test
t_statistic, p_value = stats.ttest_ind(chol_with_disease, chol_without_disease)

print("Two-Sample T-Test")
print(f"Hypotheses:")
print(f"H0: The mean cholesterol levels are equal between the two groups (with and without heart disease).")
print(f"H1: The mean cholesterol levels are not equal between the two groups.\n")

print(f"Results:")
print(f"T-statistic: {t_statistic:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Conclusion: Reject the null hypothesis (H0). There is a significant difference in mean cholesterol levels between the two groups.\n")
else:
    print("Conclusion: Fail to reject the null hypothesis (H0). No significant difference in mean cholesterol levels between the two groups.\n")
# Out:
# One-Sample T-Test
# Hypotheses:
# H0: The mean cholesterol level is 200.
# H1: The mean cholesterol level is not 200.
#
# Results:
# T-statistic: 28.5452
# P-value: 0.0000
# Conclusion: Reject the null hypothesis (H0). The mean cholesterol level is significantly different from 200.
#
# Two-Sample T-Test
# Hypotheses:
# H0: The mean cholesterol levels are equal between the two groups (with and without heart disease).
# H1: The mean cholesterol levels are not equal between the two groups.
#
# Results:
# T-statistic: -3.2134
# P-value: 0.0014
# Conclusion: Reject the null hypothesis (H0). There is a significant difference in mean cholesterol levels between the two groups.

# %% [markdown]
# ########################                      HERE ARE THREE INTERVIEW QUESTION                      ######################

# %% [markdown]
# # QUE 1. How do age and gender influence the likelihood of heart disease?
# # This question can be explored by analyzing the relationship between the age and gender columns (first two columns) and
# # the presence of heart disease (last column, where 1 likely indicates presence and 0 absence of heart disease).
#
# # QUE 2. What is the correlation between cholesterol levels and heart disease risk?
# # The dataset includes cholesterol levels (5th column), which can be analyzed in relation to the heart disease indicator to
# # determine if there's a significant correlation.
#
# # QUE 3. How do different types of chest pain (angina) relate to heart disease diagnosis?
# # The third column appears to represent different types of chest pain (values 0-3).
# # This research question would involve examining how these different types correlate with the presence or absence of heart disease.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind, pearsonr

# Load the dataset
data = pd.read_csv("C:/Users/ankuv/Downloads/Heart Disease data.csv")

# Display the first few rows of the dataset
print(data.head())

# Question 1: How do age and gender influence the likelihood of heart disease?
# Plot age distribution by heart disease presence
plt.figure(figsize=(10, 6))
sns.histplot(data[data['target'] == 1]['Age'], color='red', label='Heart Disease', kde=True)
sns.histplot(data[data['target'] == 0]['Age'], color='blue', label='No Heart Disease', kde=True)
plt.title('Age Distribution by Heart Disease Presence')
plt.xlabel('Age')
plt.legend()
plt.show()

# Gender distribution by heart disease presence
gender_counts = data.groupby(['Sex', 'target']).size().unstack()
gender_counts.plot(kind='bar', stacked=True, color=['blue', 'red'], figsize=(8, 6))
plt.title('Gender Distribution by Heart Disease Presence')
plt.xlabel('Gender (0 = Female, 1 = Male)')
plt.ylabel('Count')
plt.show()
# Out:
#    Age  Sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
# C:\Users\ankuv\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # Visualization for Question 1: Age and Gender Influence on Heart Disease
#
# # Age Distribution by Heart Disease Presence:
# # Histogram: This visualization shows the distribution of ages for patients with and without heart disease.
# # The histogram uses two colors: red for patients with heart disease and blue for those without.
# # The plot helps identify any age-related trends, such as whether older or younger individuals are more likely to have heart disease.
#
# # Gender Distribution by Heart Disease Presence:
# # Bar Chart: This chart displays the count of males and females in both the heart disease and non-heart disease groups.
# # It uses stacked bars to compare the gender distribution, providing insights into whether one gender is more affected by heart disease than the other.

# %%
# Question 2: What is the correlation between cholesterol levels and heart disease risk?
# Calculate correlation
chol_corr, _ = pearsonr(data['chol'], data['target'])
print(f"Correlation between cholesterol levels and heart disease: {chol_corr:.2f}")

# Scatter plot of cholesterol levels vs heart disease
plt.figure(figsize=(10, 6))
sns.scatterplot(x='chol', y='target', data=data, alpha=0.5)
plt.title('Cholesterol Levels vs Heart Disease Presence')
plt.xlabel('Cholesterol Level')
plt.ylabel('Heart Disease Presence (0 = No, 1 = Yes)')
plt.show()
# Out:
# Correlation between cholesterol levels and heart disease: -0.10

# %% [markdown]
# # Visualization for Question 2: Correlation Between Cholesterol Levels and Heart Disease Risk
#
# # Scatter Plot of Cholesterol Levels vs. Heart Disease Presence:
# # Scatter Plot: This plot visualizes the relationship between cholesterol levels and the presence of heart disease.
# # Each point represents an individual's cholesterol level and whether they have heart disease (target).
# # The scatter plot helps identify any patterns or trends, such as whether higher cholesterol levels correlate with an increased risk of heart disease.

# %%
# Question 3: How do different types of chest pain relate to heart disease diagnosis?
# Chest pain type distribution by heart disease presence
cp_counts = data.groupby(['cp', 'target']).size().unstack()
cp_counts.plot(kind='bar', stacked=True, color=['blue', 'red'], figsize=(8, 6))
plt.title('Chest Pain Type Distribution by Heart Disease Presence')
plt.xlabel('Chest Pain Type (0-3)')
plt.ylabel('Count')
plt.show()

# Statistical test: T-test for age difference
age_with_disease = data[data['target'] == 1]['Age']
age_without_disease = data[data['target'] == 0]['Age']
t_stat, p_value = ttest_ind(age_with_disease, age_without_disease)
print(f"T-test for age difference: t-statistic = {t_stat:.2f}, p-value = {p_value:.2f}")
# Out:
# T-test for age difference: t-statistic = -7.54, p-value = 0.00

# %% [markdown]
# # Visualization for Question 3: Chest Pain Types and Heart Disease Diagnosis
#
# # Chest Pain Type Distribution by Heart Disease Presence:
# # Bar Chart: This chart shows the distribution of different chest pain types among patients with and without heart disease.
# # The chest pain types are represented by values 0 to 3, and the chart uses stacked bars to compare the frequency of each type in both groups.
# # This visualization helps determine which chest pain types are more commonly associated with heart disease.
